# %%
import numpy as np
import pandas as pd
height = [120,122,127,143,148,131,163,185,192,156,177,189,139,184,186]
bins = [118, 125, 135, 160, 200]
category=pd.cut(height,bins)
category
# Out:
# [(118, 125], (118, 125], (125, 135], (135, 160], (135, 160], ..., (160, 200], (160, 200], (135, 160], (160, 200], (160, 200]]
# Length: 15
# Categories (4, interval[int64, right]): [(118, 125] < (125, 135] < (135, 160] < (160, 200]]

# %%
pd.value_counts(category)
# Out:
# /tmp/ipykernel_729/1463743115.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category)
# (160, 200]    7
# (135, 160]    4
# (125, 135]    2
# (118, 125]    2
# Name: count, dtype: int64

# %%
bin_names = ['Short Height', 'Average height', 'Good Height', 'Taller']
pd.cut(height, bins, labels=bin_names)
# Out:
# ['Short Height', 'Short Height', 'Average height', 'Good Height', 'Good Height', ..., 'Taller', 'Taller', 'Good Height', 'Taller', 'Taller']
# Length: 15
# Categories (4, object): ['Short Height' < 'Average height' < 'Good Height' < 'Taller']

# %%
pd.cut(np.random.rand(40), 5, precision=2)
# Out:
# [(0.61, 0.8], (0.61, 0.8], (0.61, 0.8], (0.24, 0.43], (0.43, 0.61], ..., (0.61, 0.8], (0.43, 0.61], (0.048, 0.24], (0.43, 0.61], (0.24, 0.43]]
# Length: 40
# Categories (5, interval[float64, right]): [(0.048, 0.24] < (0.24, 0.43] < (0.43, 0.61] < (0.61, 0.8] <
#                                            (0.8, 0.99]]

# %%
randomNumbers = np.random.rand(2000)
category3 = pd.qcut(randomNumbers, 4)
category3
# Out:
# [(0.00117, 0.263], (0.771, 1.0], (0.263, 0.504], (0.263, 0.504], (0.263, 0.504], ..., (0.00117, 0.263], (0.771, 1.0], (0.504, 0.771], (0.00117, 0.263], (0.263, 0.504]]
# Length: 2000
# Categories (4, interval[float64, right]): [(0.00117, 0.263] < (0.263, 0.504] < (0.504, 0.771] <
#                                            (0.771, 1.0]]

# %%
pd.value_counts(category3)
# Out:
# /tmp/ipykernel_729/647498483.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(category3)
# (0.00117, 0.263]    500
# (0.263, 0.504]      500
# (0.504, 0.771]      500
# (0.771, 1.0]        500
# Name: count, dtype: int64

# %%
df=pd.read_csv('/fraudTest.csv')
df.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
# 5           5   2020-06-21 12:15:37    30407675418785
# 6           6   2020-06-21 12:15:44   213180742685905
# 7           7   2020-06-21 12:15:50  3589289942931264
# 8           8   2020-06-21 12:16:10  3596357274378601
# 9           9   2020-06-21 12:16:11  3546897637165774
#
#                                merchant        category     amt     first  \
# 0                 fraud_Kirlin and Sons   personal_care    2.86      Jeff
# 1                  fraud_Sporer-Keebler   personal_care   29.84    Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness   41.28    Ashley
# ...

# %%
TotalTransaction = df["amt"]
TotalTransaction[np.abs(TotalTransaction)>1000]
# Out:
# 167       1199.45
# 428       1881.53
# 951       3204.98
# 999       2068.05
# 1398      1420.90
#            ...
# 157839    2886.52
# 158014    1153.92
# 158072    1000.46
# 158127    1019.77
# 158895    2111.72
# Name: amt, Length: 455, dtype: float64

# %%
df[np.abs(TotalTransaction) > 10000]
# Out:
#        Unnamed: 0 trans_date_trans_time               cc_num  \
# 35542       35542   2020-07-03 18:13:00  4797297220948468262
# 77413       77413   2020-07-18 14:14:57     3501509250702469
# 87794       87794   2020-07-21 13:01:31     3598895972308782
#
#                                     merchant category       amt    first  \
# 35542     fraud_Hagenes, Hermann and Stroman   travel  13149.15    Erica
# 77413               fraud_Romaguera and Sons   travel  12882.78    Frank
# 87794  fraud_Ritchie, Oberbrunner and Cremin   travel  12882.33  Kenneth
#
#            last gender                               street  ...      lat  \
# 35542    Briggs      F         3310 Davidson Spurs Apt. 107  ...  38.8938
# 77413  Anderson      M       0611 Stafford Valley Suite 504  ...  26.1184
# 87794  Richards      M  994 Livingston Extensions Suite 918  ...  41.2403
#
#           long  city_pop                                            job  \
# ...

# %%
df=pd.read_csv('/fraudTrain.csv')
df
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 0                0   2019-01-01 00:00:18  2703186189652095
# 1                1   2019-01-01 00:00:44      630423337322
# 2                2   2019-01-01 00:00:51    38859492057661
# 3                3   2019-01-01 00:01:16  3534093764340240
# 4                4   2019-01-01 00:03:06   375534208663984
# ...            ...                   ...               ...
# 112748      112748   2019-03-04 21:44:03      676195318214
# 112749      112749   2019-03-04 21:44:32  4128027264554082
# 112750      112750   2019-03-04 21:44:53   213153151785052
# 112751      112751   2019-03-04 21:45:08    38588538868506
# 112752      112752   2019-03-04 21:45:44  4998109455173950
#
#                                      merchant        category     amt  \
# 0                  fraud_Rippin, Kub and Mann        misc_net    4.97
# 1             fraud_Heller, Gutmann and Zieme     grocery_pos  107.23
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
# 5           5   2019-01-01 00:04:08  4767265376804500
# 6           6   2019-01-01 00:04:42    30074693890476
# 7           7   2019-01-01 00:05:08  6011360759745864
# 8           8   2019-01-01 00:05:18  4922710831011201
# 9           9   2019-01-01 00:06:01  2720830304681674
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# ...

# %%
df.tail(10)
# Out:
#         Unnamed: 0 trans_date_trans_time            cc_num  \
# 112743      112743   2019-03-04 21:42:47  3565196229855512
# 112744      112744   2019-03-04 21:42:49  4377338765909719
# 112745      112745   2019-03-04 21:43:16   375848982312810
# 112746      112746   2019-03-04 21:43:39    30238755902988
# 112747      112747   2019-03-04 21:43:48   375974680629816
# 112748      112748   2019-03-04 21:44:03      676195318214
# 112749      112749   2019-03-04 21:44:32  4128027264554082
# 112750      112750   2019-03-04 21:44:53   213153151785052
# 112751      112751   2019-03-04 21:45:08    38588538868506
# 112752      112752   2019-03-04 21:45:44  4998109455173950
#
#                                      merchant        category     amt  \
# 112743     fraud_O'Connell, Botsford and Hand            home   24.70
# 112744                   fraud_Schoen-Quigley       kids_pets   50.81
# 112745               fraud_Waters-Cruickshank  health_fitness  250.65
# ...

# %%
Category = df["city_pop"]
Category[np.abs(Category)>100000]
# Out:
# 9          151785
# 12         341043
# 19         124967
# 33         378909
# 34         601723
#            ...
# 112724    2906700
# 112726     123373
# 112737     276896
# 112741     413574
# 112752     545147
# Name: city_pop, Length: 15648, dtype: int64

# %%
TotalTransaction = df["amt"]
TotalTransaction[np.abs(TotalTransaction)>1000]
# Out:
# 232       1055.47
# 511       1636.87
# 723       1047.52
# 824       1433.54
# 1480      1025.38
#            ...
# 111368    1558.65
# 111525    1408.12
# 111713    3498.36
# 112014    1064.13
# 112422    2229.67
# Name: amt, Length: 397, dtype: float64

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
data={'Age': [25,38,30,37,42,45,35,22,48,21],'Salary': [50000,64000,120000,85000,1200000,600000,85000,1100000,450000,900000]}
df=pd.DataFrame(data)
print("Original Data:\n",df,"\n")
# Out:
# Original Data:
#     Age   Salary
# 0   25    50000
# 1   38    64000
# 2   30   120000
# 3   37    85000
# 4   42  1200000
# 5   45   600000
# 6   35    85000
# 7   22  1100000
# 8   48   450000
# 9   21   900000

# %%
min_max_scaler=MinMaxScaler()
df_min_max=pd.DataFrame(min_max_scaler.fit_transform(df),columns=df.columns)
print("Min-Max Scaled Data:\n",df_min_max,"\n")
# Out:
# Min-Max Scaled Data:
#          Age    Salary
# 0  0.148148  0.000000
# 1  0.629630  0.012174
# 2  0.333333  0.060870
# 3  0.592593  0.030435
# 4  0.777778  1.000000
# 5  0.888889  0.478261
# 6  0.518519  0.030435
# 7  0.037037  0.913043
# 8  1.000000  0.347826
# 9  0.000000  0.739130

# %%
standard_scaler=StandardScaler()
df_standard=pd.DataFrame(standard_scaler.fit_transform(df),columns=df.columns)
print("Standardized Data:\n",df_standard,"\n")
# Out:
# Standardized Data:
#          Age    Salary
# 0 -1.029464 -0.955012
# 1  0.409572 -0.922826
# 2 -0.475989 -0.794081
# 3  0.298877 -0.874546
# 4  0.852352  1.688859
# 5  1.184437  0.309448
# 6  0.077487 -0.874546
# 7 -1.361549  1.458957
# 8  1.516523 -0.035405
# 9 -1.472245  0.999153
