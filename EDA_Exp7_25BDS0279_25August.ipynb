# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
df=pd.read_csv("/content/Iris.csv")

# %%
df.SepalLengthCm.value_counts().nlargest(7).plot(kind='bar',figsize=(10,6))
plt.title("SepalLength vs SepalWidth")
plt.ylabel('Sepal Length(in cm)')
plt.xlabel('Sepal Width(in cm)')
# Out:
# Text(0.5, 0, 'Sepal Width(in cm)')

# %%
sns.FacetGrid(df).map(sns.displot,"SepalLengthCm").add_legend()
# Out:
# /usr/local/lib/python3.13/dist-packages/seaborn/distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df).map(sns.displot,"SepalWidthCm").add_legend()
# Out:
# /usr/local/lib/python3.13/dist-packages/seaborn/distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(df).map(sns.displot,"Species").add_legend()
# Out:
# /usr/local/lib/python3.13/dist-packages/seaborn/distributions.py:2125: UserWarning: `displot` is a figure-level function and does not accept the ax= parameter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x="SepalLengthCm",data=df)
# Out:
# <Axes: xlabel='SepalLengthCm'>

# %%
sns.boxplot(x="Species",data=df)
# Out:
# <Axes: xlabel='Species'>

# %%
sns.boxplot(x="PetalLengthCm",data=df)
# Out:
# <Axes: xlabel='PetalLengthCm'>

# %%
sns.boxplot(x="SepalWidthCm",data=df)
# Out:
# <Axes: xlabel='SepalWidthCm'>

# %%
sns.boxplot(x="PetalWidthCm",data=df)
# Out:
# <Axes: xlabel='PetalWidthCm'>

# %%
plt.scatter(df["SepalLengthCm"],df["SepalWidthCm"])
plt.title("Scatter Plot for SepalLengthCm vs SepalWidthCm")
plt.xlabel("SepalWidthCm")
plt.ylabel("SepalLengthCm")
# Out:
# Text(0, 0.5, 'SepalLengthCm')

# %%
plt.scatter(df["PetalLengthCm"],df["PetalWidthCm"])
plt.title("Scatter Plot for PetalLengthCm vs PetalWidthCm")
plt.xlabel("PetalWidthCm")
plt.ylabel("PetalLengthCm")
# Out:
# Text(0, 0.5, 'PetalLengthCm')

# %%
sns.boxplot(x="SepalWidthCm",y="SepalLengthCm",data=df)
plt.show()

# %%
sns.boxplot(x="Species",y="Id",data=df)
plt.show()

# %%
sns.boxplot(x="Species",y="SepalLengthCm",data=df)
plt.show()

# %%
sns.boxplot(x="Species",y="SepalWidthCm",data=df)
plt.show()

# %%
sns.pairplot(df,vars=['SepalLengthCm','SepalWidthCm','PetalLengthCm'],kind="reg")
plt.show()

# %%
sns.set(style="ticks",color_codes=True)
sns.pairplot(df,height=2,vars=['SepalLengthCm','SepalWidthCm','PetalLengthCm'],hue='Species')
plt.show()

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_577/2514664511.py in <cell line: 0>()
# ----> 1 sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns)
#
# NameError: name 'correlation' is not defined
